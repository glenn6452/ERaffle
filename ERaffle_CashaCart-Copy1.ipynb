# %%
import numpy as np
import pandas as pd
import MySQLdb

# %%
# Read the sql file
query = open('script.sql', 'r')

connection = MySQLdb.connect(host='prod-rep3.cfti8umsjnvm.ap-southeast-1.rds.amazonaws.com', 
                port=3306,user='cashacart_monitor', passwd='aabb1122', 
                db='trade')
# connection == the connection to your database, in your case prob_db
df = pd.read_sql_query(query.read(),connection)


#df = pd.read_csv('sample.csv')
#df.head()

# %%
df
# Out:
#     accountId                        client_name date_applied  \
# 0     1325808        Mark Ranier Bernabe Agunoy    2019-05-28
# 1      281212          donnabel poliquit lumagod   2019-05-28
# 2     1340129                 Lizel Galit Aguila   2019-05-29
# 3     1340221        Shiela Marie Catapat Banaag   2019-05-29
# 4      188745           Anna Marie Faller Pinlac   2019-05-29
# 5     1333657  Maria Cristina Cabilatazan Lontoc   2019-05-29
# 6      307961        divina grace calivo meneses   2019-05-30
# 7      307650         jaenalyn gebilaguin mosote   2019-05-30
# 8      621383       maria jane bonquin crisologo   2019-05-30
# 9     1345799                reny napaton desaca   2019-05-30
# 10     548651                Nelmar Munez burlas   2019-05-30
# 11    1346094              jayson bosquit pangan   2019-05-30
# 12    1333669               jocelyn agub fugaban   2019-05-30
# 13    1346231             rodalyn gumarang gamit   2019-05-30
# 14    1346352              Cheryl Padilla Ordona   2019-05-30
# 15    1346623                Jonel Armero Verano   2019-05-30
# 16     564389           Evelyn Beconiado Tomenio   2019-05-30
# 17     281212          donnabel poliquit lumagod   2019-05-28
# 18    1340129                 Lizel Galit Aguila   2019-05-29
# 19     188745           Anna Marie Faller Pinlac   2019-05-29
# 20    1333657  Maria Cristina Cabilatazan Lontoc   2019-05-29
# 21     621383       maria jane bonquin crisologo   2019-05-30
# 22     548651                Nelmar Munez burlas   2019-05-30
# 23    1333669               jocelyn agub fugaban   2019-05-30
# 24    1346231             rodalyn gumarang gamit   2019-05-30
# 25    1346352              Cheryl Padilla Ordona   2019-05-30
# 26    1346623                Jonel Armero Verano   2019-05-30
# 27     281212          donnabel poliquit lumagod   2019-05-28
# 28     188745           Anna Marie Faller Pinlac   2019-05-29
# 29     621383       maria jane bonquin crisologo   2019-05-30
# 30    1333669               jocelyn agub fugaban   2019-05-30
# 31    1346231             rodalyn gumarang gamit   2019-05-30
# 32    1346623                Jonel Armero Verano   2019-05-30
# 33     281212          donnabel poliquit lumagod   2019-05-28
# 34     188745           Anna Marie Faller Pinlac   2019-05-29
# 35     621383       maria jane bonquin crisologo   2019-05-30
# 36    1333669               jocelyn agub fugaban   2019-05-30
# 37    1346231             rodalyn gumarang gamit   2019-05-30
# 38     621383       maria jane bonquin crisologo   2019-05-30
# 39     621383       maria jane bonquin crisologo   2019-05-30
# 40     621383       maria jane bonquin crisologo   2019-05-30
# 41     621383       maria jane bonquin crisologo   2019-05-30
# 42     621383       maria jane bonquin crisologo   2019-05-30
# 43     621383       maria jane bonquin crisologo   2019-05-30
#
#              orderNo  billAmount ticket_type  \
# 0   B190528124241746      3000.0         B2S
# 1   B190528124242104     10000.0         B2S
# 2   B190529124244955      5000.0         B2S
# 3   B190529124245075      2500.0         B2S
# 4   B190529124247400     11000.0         B2S
# 5   B190529124248429      5000.0         B2S
# 6   B190530124250811      4900.0         B2S
# 7   B190530124250860      4900.0         B2S
# 8   B190530124251100     13000.0       B2SRC
# 9   B190530124252109      2995.0         B2S
# 10  B190530124252454      4500.0       B2SRC
# 11  B190530124252573      4205.0         B2S
# 12  B190530124252729      5000.0       B2SRC
# 13  B190530124252903      6089.0       B2SRC
# 14  B190530124253048      3000.0       B2SRC
# 15  B190530124253405      8599.0         B2S
# 16  B190530124253478      2500.0         B2S
# 17  B190528124242104     10000.0         B2S
# 18  B190529124244955      5000.0         B2S
# 19  B190529124247400     11000.0         B2S
# 20  B190529124248429      5000.0         B2S
# 21  B190530124251100     13000.0       B2SRC
# 22  B190530124252454      4500.0       B2SRC
# 23  B190530124252729      5000.0       B2SRC
# 24  B190530124252903      6089.0       B2SRC
# 25  B190530124253048      3000.0       B2SRC
# 26  B190530124253405      8599.0         B2S
# 27  B190528124242104     10000.0         B2S
# 28  B190529124247400     11000.0         B2S
# 29  B190530124251100     13000.0       B2SRC
# 30  B190530124252729      5000.0       B2SRC
# 31  B190530124252903      6089.0       B2SRC
# 32  B190530124253405      8599.0         B2S
# 33  B190528124242104     10000.0         B2S
# 34  B190529124247400     11000.0         B2S
# 35  B190530124251100     13000.0       B2SRC
# 36  B190530124252729      5000.0       B2SRC
# 37  B190530124252903      6089.0       B2SRC
# 38  B190530124251100     13000.0       B2SRC
# 39  B190530124251100     13000.0       B2SRC
# 40  B190530124251100     13000.0       B2SRC
# 41  B190530124251100     13000.0       B2SRC
# 42  B190530124251100     13000.0       B2SRC
# 43  B190530124251100     13000.0       B2SRC
#
#                                       pos_name  pos_code          ticket_code
# 0            Robinsons Department Store - Lipa  RDS00002   B190528124241746-1
# 1        Robinsons Department Store - Galleria  RDS00004   B190528124242104-1
# 2            Robinsons Department Store - Lipa  RDS00002   B190529124244955-1
# 3            Robinsons Department Store - Lipa  RDS00002   B190529124245075-1
# 4      Robinsons Department Store - Cloverleaf  RDS00011   B190529124247400-1
# 5         Robinsons Department Store - Pioneer  RDS00008   B190529124248429-1
# 6         Robinsons Department Store - Pioneer  RDS00008   B190530124250811-1
# 7         Robinsons Department Store - Pioneer  RDS00008   B190530124250860-1
# 8   Robinsons Department Store - General Trias  RDS00015   B190530124251100-1
# 9        Robinsons Department Store - Galleria  RDS00004   B190530124252109-1
# 10         Robinsons Department Store - Ermita  RDS00010   B190530124252454-1
# 11       Robinsons Department Store - Galleria  RDS00004   B190530124252573-1
# 12        Robinsons Department Store - Pioneer  RDS00008   B190530124252729-1
# 13  Robinsons Department Store - General Trias  RDS00015   B190530124252903-1
# 14  Robinsons Department Store - General Trias  RDS00015   B190530124253048-1
# 15       Robinsons Department Store - Galleria  RDS00004   B190530124253405-1
# 16  Robinsons Department Store - General Trias  RDS00015   B190530124253478-1
# 17       Robinsons Department Store - Galleria  RDS00004   B190528124242104-2
# 18           Robinsons Department Store - Lipa  RDS00002   B190529124244955-2
# 19     Robinsons Department Store - Cloverleaf  RDS00011   B190529124247400-2
# 20        Robinsons Department Store - Pioneer  RDS00008   B190529124248429-2
# 21  Robinsons Department Store - General Trias  RDS00015   B190530124251100-2
# 22         Robinsons Department Store - Ermita  RDS00010   B190530124252454-2
# 23        Robinsons Department Store - Pioneer  RDS00008   B190530124252729-2
# 24  Robinsons Department Store - General Trias  RDS00015   B190530124252903-2
# 25  Robinsons Department Store - General Trias  RDS00015   B190530124253048-2
# 26       Robinsons Department Store - Galleria  RDS00004   B190530124253405-2
# 27       Robinsons Department Store - Galleria  RDS00004   B190528124242104-3
# 28     Robinsons Department Store - Cloverleaf  RDS00011   B190529124247400-3
# 29  Robinsons Department Store - General Trias  RDS00015   B190530124251100-3
# 30        Robinsons Department Store - Pioneer  RDS00008   B190530124252729-3
# 31  Robinsons Department Store - General Trias  RDS00015   B190530124252903-3
# 32       Robinsons Department Store - Galleria  RDS00004   B190530124253405-3
# 33       Robinsons Department Store - Galleria  RDS00004   B190528124242104-4
# 34     Robinsons Department Store - Cloverleaf  RDS00011   B190529124247400-4
# 35  Robinsons Department Store - General Trias  RDS00015   B190530124251100-4
# 36        Robinsons Department Store - Pioneer  RDS00008   B190530124252729-4
# 37  Robinsons Department Store - General Trias  RDS00015   B190530124252903-4
# 38  Robinsons Department Store - General Trias  RDS00015   B190530124251100-5
# 39  Robinsons Department Store - General Trias  RDS00015   B190530124251100-6
# 40  Robinsons Department Store - General Trias  RDS00015   B190530124251100-7
# 41  Robinsons Department Store - General Trias  RDS00015   B190530124251100-8
# 42  Robinsons Department Store - General Trias  RDS00015   B190530124251100-9
# 43  Robinsons Department Store - General Trias  RDS00015  B190530124251100-10

# %%
# Declartion of the Dataset per RDS POS
RDS00001=df.loc[df['pos_code']=='RDS00001']
RDS00002=df.loc[df['pos_code']=='RDS00002']
RDS00003=df.loc[df['pos_code']=='RDS00003']
RDS00004=df.loc[df['pos_code']=='RDS00004']
RDS00005=df.loc[df['pos_code']=='RDS00005']
RDS00006=df.loc[df['pos_code']=='RDS00006']
RDS00007=df.loc[df['pos_code']=='RDS00007']
RDS00008=df.loc[df['pos_code']=='RDS00008']
RDS00009=df.loc[df['pos_code']=='RDS00009']
RDS00010=df.loc[df['pos_code']=='RDS00010']
RDS00011=df.loc[df['pos_code']=='RDS00011']
RDS00012=df.loc[df['pos_code']=='RDS00012']
RDS00013=df.loc[df['pos_code']=='RDS00013']
RDS00014=df.loc[df['pos_code']=='RDS00014']
RDS00015=df.loc[df['pos_code']=='RDS00015']
RDS00016=df.loc[df['pos_code']=='RDS00016']

# %%
RDS00002[]
# Out:
#     accountId                  client_name date_applied           orderNo  \
# 0     1325808  Mark Ranier Bernabe Agunoy    2019-05-28  B190528124241746
# 2     1340129           Lizel Galit Aguila   2019-05-29  B190529124244955
# 3     1340221  Shiela Marie Catapat Banaag   2019-05-29  B190529124245075
# 18    1340129           Lizel Galit Aguila   2019-05-29  B190529124244955
#
#     billAmount ticket_type                           pos_name  pos_code  \
# 0       3000.0         B2S  Robinsons Department Store - Lipa  RDS00002
# 2       5000.0         B2S  Robinsons Department Store - Lipa  RDS00002
# 3       2500.0         B2S  Robinsons Department Store - Lipa  RDS00002
# 18      5000.0         B2S  Robinsons Department Store - Lipa  RDS00002
#
#            ticket_code
# 0   B190528124241746-1
# 2   B190529124244955-1
# 3   B190529124245075-1
# 18  B190529124244955-2

# %%
#Declaring the ticket_code to be evaluated for the raffle 
RDS00001_ENTRIES=RDS00001.ticket_code
RDS00002_ENTRIES=RDS00002.ticket_code
RDS00003_ENTRIES=RDS00003.ticket_code
RDS00004_ENTRIES=RDS00004.ticket_code
RDS00005_ENTRIES=RDS00005.ticket_code
RDS00006_ENTRIES=RDS00006.ticket_code
RDS00007_ENTRIES=RDS00007.ticket_code
RDS00008_ENTRIES=RDS00008.ticket_code
RDS00009_ENTRIES=RDS00009.ticket_code
RDS00010_ENTRIES=RDS00010.ticket_code
RDS00011_ENTRIES=RDS00011.ticket_code
RDS00012_ENTRIES=RDS00012.ticket_code
RDS00013_ENTRIES=RDS00013.ticket_code
RDS00014_ENTRIES=RDS00014.ticket_code
RDS00015_ENTRIES=RDS00015.ticket_code
RDS00016_ENTRIES=RDS00016.ticket_code

# %%
# Declaring the winners for each RDS POS
#RDS00001_WINNERS=np.random.choice(RDS00001_ENTRIES, 2, replace=False)
RDS00002_WINNERS=np.random.choice(RDS00002_ENTRIES, 2, replace=False)
#RDS00003_WINNERS=np.random.choice(RDS00003_ENTRIES, 2, replace=False)
RDS00004_WINNERS=np.random.choice(RDS00004_ENTRIES, 2, replace=False)
#RDS00005_WINNERS=np.random.choice(RDS00005_ENTRIES, 2, replace=False)
#RDS00006_WINNERS=np.random.choice(RDS00006_ENTRIES, 2, replace=False)
#RDS00007_WINNERS=np.random.choice(RDS00007_ENTRIES, 2, replace=False)
RDS00008_WINNERS=np.random.choice(RDS00008_ENTRIES, 2, replace=False)
#RDS00009_WINNERS=np.random.choice(RDS00009_ENTRIES, 2, replace=False)
RDS00010_WINNERS=np.random.choice(RDS00010_ENTRIES, 2, replace=False)
RDS00011_WINNERS=np.random.choice(RDS00011_ENTRIES, 2, replace=False)
#RDS00012_WINNERS=np.random.choice(RDS00012_ENTRIES, 2, replace=False)
#RDS00013_WINNERS=np.random.choice(RDS00013_ENTRIES, 2, replace=False)
#RDS00014_WINNERS=np.random.choice(RDS00014_ENTRIES, 2, replace=False)
RDS00015_WINNERS=np.random.choice(RDS00015_ENTRIES, 2, replace=False)
#RDS00016_WINNERS=np.random.choice(RDS00016_ENTRIES, 2, replace=False)

# %%
ALL_WINNERS = np.concatenate((#RDS00001_WINNERS,
RDS00002_WINNERS,
#RDS00003_WINNERS,
RDS00004_WINNERS,
#RDS00005_WINNERS,
#RDS00006_WINNERS,
#RDS00007_WINNERS,
RDS00008_WINNERS,
#RDS00009_WINNERS,
RDS00010_WINNERS,
RDS00011_WINNERS,
#RDS00012_WINNERS,
#RDS00013_WINNERS,
#RDS00014_WINNERS,
RDS00015_WINNERS#,
#RDS00016_WINNERS
),axis=0)
ALL_WINNERS
# Out:
# array(['B190529124244955-1', 'B190529124244955-2', 'B190528124242104-3',
#        'B190530124253405-2', 'B190530124250811-1', 'B190530124252729-4',
#        'B190530124252454-2', 'B190530124252454-1', 'B190529124247400-3',
#        'B190529124247400-2', 'B190530124251100-2', 'B190530124251100-1'],
#       dtype=object)

# %%
winners = df.loc[df['ticket_code'].isin(ALL_WINNERS)].sort_values('pos_code')
winners
# Out:
#     accountId                   client_name date_applied           orderNo  \
# 2     1340129            Lizel Galit Aguila   2019-05-29  B190529124244955
# 18    1340129            Lizel Galit Aguila   2019-05-29  B190529124244955
# 26    1346623           Jonel Armero Verano   2019-05-30  B190530124253405
# 27     281212     donnabel poliquit lumagod   2019-05-28  B190528124242104
# 6      307961   divina grace calivo meneses   2019-05-30  B190530124250811
# 36    1333669          jocelyn agub fugaban   2019-05-30  B190530124252729
# 10     548651           Nelmar Munez burlas   2019-05-30  B190530124252454
# 22     548651           Nelmar Munez burlas   2019-05-30  B190530124252454
# 19     188745      Anna Marie Faller Pinlac   2019-05-29  B190529124247400
# 28     188745      Anna Marie Faller Pinlac   2019-05-29  B190529124247400
# 8      621383  maria jane bonquin crisologo   2019-05-30  B190530124251100
# 21     621383  maria jane bonquin crisologo   2019-05-30  B190530124251100
#
#     billAmount ticket_type                                    pos_name  \
# 2       5000.0         B2S           Robinsons Department Store - Lipa
# 18      5000.0         B2S           Robinsons Department Store - Lipa
# 26      8599.0         B2S       Robinsons Department Store - Galleria
# 27     10000.0         B2S       Robinsons Department Store - Galleria
# 6       4900.0         B2S        Robinsons Department Store - Pioneer
# 36      5000.0       B2SRC        Robinsons Department Store - Pioneer
# 10      4500.0       B2SRC         Robinsons Department Store - Ermita
# 22      4500.0       B2SRC         Robinsons Department Store - Ermita
# 19     11000.0         B2S     Robinsons Department Store - Cloverleaf
# 28     11000.0         B2S     Robinsons Department Store - Cloverleaf
# 8      13000.0       B2SRC  Robinsons Department Store - General Trias
# 21     13000.0       B2SRC  Robinsons Department Store - General Trias
#
#     pos_code         ticket_code
# 2   RDS00002  B190529124244955-1
# 18  RDS00002  B190529124244955-2
# 26  RDS00004  B190530124253405-2
# 27  RDS00004  B190528124242104-3
# 6   RDS00008  B190530124250811-1
# 36  RDS00008  B190530124252729-4
# 10  RDS00010  B190530124252454-1
# 22  RDS00010  B190530124252454-2
# 19  RDS00011  B190529124247400-2
# 28  RDS00011  B190529124247400-3
# 8   RDS00015  B190530124251100-1
# 21  RDS00015  B190530124251100-2

# %%
winners.to_csv('winners.csv')

# %%
from pd2ppt import df_to_powerpoint
import pandas as pd

df = pd.DataFrame(
    {'District':['Hampshire', 'Dorset', 'Wiltshire', 'Worcestershire'],
     'Population':[25000, 500000, 735298, 12653],
     'Ratio':[1.56, 7.34, 3.67, 8.23]})

df_to_powerpoint('test58.pptx', df, col_formatters=['', ',', '.2'],
    rounding=['', 3, ''])
